# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
activities_df = pd.read_csv('./TrainingDataPD25/TrainingDataPD25/TrainActivities.csv')

# %%
expected_columns = ["ID", "Activity Type ID", "Activity Type", "Started", "Finished", "Updated", "Subject"]
if list(activities_df.columns) != expected_columns:
    raise ValueError(f"header is different from what expected {df.columns.tolist()}")

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 0)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
display(activities_df)
# Out:
#           ID  Activity Type ID  \
# 0    1130251              2806
# 1    1130254              2807
# 2    1130257              2807
# 3    1130261              2806
# 4    1130292              2806
# 5    1130293              2807
# 6    1130294              2808
# 7    1130306              2806
# 8    1136872              2806
# 9    1136878              2807
# 10   1136882              2807
# 11   1136887              2807
# 12   1136888              2808
# 13   1136889              2808
# 14   1136890              2808
# 15   1136896              2809
# 16   1136898              2809
# 17   1136900              2809
# 18   1136903              2810
# 19   1136904              2810
# 20   1136906              2810
# 21   1136908              2811
# 22   1136909              2811
# 23   1136910              2811
# 24   1136911              2812
# 25   1136913              2813
# 26   1136915              2813
# 27   1136916              2813
# 28   1136917              2814
# ...

# %%
import os
DIR = './TrainingDataPD25/TrainingDataPD25/users_timeXYZ/users/'
total_files = 0
for name in os.listdir(DIR):
    subdir = os.path.join(DIR, name)
    if os.path.isdir(subdir):
        files = [f for f in os.listdir(subdir) if os.path.isfile(os.path.join(subdir, f))]
        total_files += len(files)
print(total_files)
# Out:
# 3530

# %%
expected_columns = ["directory", "subject", "timestamp", "x", "y", "z", "activity_type"]
labeled_sensor_df = pd.read_csv('./labeled_sensor_data.csv')
display(labeled_sensor_df)
# Out:
#      directory subject                         timestamp      x      y      z  \
# 0         2807      U3  2024-09-05 21:25:00.002000+01:00  1.896 -0.558  9.938
# 1         2807      U3  2024-09-05 21:25:00.162000+01:00  1.903 -0.536  9.938
# 2         2807      U3  2024-09-05 21:25:00.325000+01:00  1.884 -0.575  9.936
# 3         2807      U3  2024-09-05 21:25:00.481000+01:00  1.894 -0.551  9.924
# 4         2807      U3  2024-09-05 21:25:00.642000+01:00  1.877 -0.577  9.922
# 5         2807      U3  2024-09-05 21:25:00.803000+01:00  1.875 -0.579  9.936
# 6         2807      U3  2024-09-05 21:25:00.961000+01:00  1.899 -0.572  9.934
# 7         2807      U3  2024-09-05 21:25:01.122000+01:00  1.891 -0.558  9.929
# 8         2807      U3  2024-09-05 21:25:01.282000+01:00  1.899 -0.572  9.931
# 9         2807      U3  2024-09-05 21:25:01.444000+01:00  1.896 -0.589  9.924
# 10        2807      U3  2024-09-05 21:25:01.601000+01:00  1.889 -0.572  9.919
# ...
